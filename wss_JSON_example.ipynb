# %% [markdown]
# ## an example of code that lets you iterate through the structure of a JSON file

# %%
import requests

search_url = 'https://www.airbnb.com/api/v2/calendar_months?_format=with_conditions&count=4&listing_id=9595397&month=9&year=2020&key=d306zoyjsyarp7ifhu67rjxn52tv0t20&currency=USD&locale=en'
header = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36"}
response = requests.get(search_url, headers=header)

root=response.json()

days = root['calendar_months'][0]['days']
print('Type of variable days: ', type(days))
for day in days:
    print('Data type of day: ', type(day))
    for k,v in day.items():
        print(k, ': ',v)
    print()
# Out:
# Type of variable days:  <class 'list'>
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-08-30
# available_for_checkin :  True
# price :  {'date': '2020-08-30', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-08-31
# available_for_checkin :  True
# price :  {'date': '2020-08-31', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-01
# available_for_checkin :  True
# price :  {'date': '2020-09-01', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-02
# available_for_checkin :  False
# price :  {'date': '2020-09-02', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-03
# available_for_checkin :  False
# price :  {'date': '2020-09-03', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-04
# available_for_checkin :  False
# price :  {'date': '2020-09-04', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-05
# available_for_checkin :  False
# price :  {'date': '2020-09-05', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-06
# available_for_checkin :  False
# price :  {'date': '2020-09-06', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-07
# available_for_checkin :  False
# price :  {'date': '2020-09-07', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-08
# available_for_checkin :  False
# price :  {'date': '2020-09-08', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  False
# date :  2020-09-09
# available_for_checkin :  False
# price :  {'date': '2020-09-09', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  False
# date :  2020-09-10
# available_for_checkin :  False
# price :  {'date': '2020-09-10', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  False
# date :  2020-09-11
# available_for_checkin :  False
# price :  {'date': '2020-09-11', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  False
# date :  2020-09-12
# available_for_checkin :  False
# price :  {'date': '2020-09-12', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  False
# date :  2020-09-13
# available_for_checkin :  False
# price :  {'date': '2020-09-13', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  False
# date :  2020-09-14
# available_for_checkin :  False
# price :  {'date': '2020-09-14', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-15
# available_for_checkin :  True
# price :  {'date': '2020-09-15', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-16
# available_for_checkin :  True
# price :  {'date': '2020-09-16', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-17
# available_for_checkin :  True
# price :  {'date': '2020-09-17', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-18
# available_for_checkin :  True
# price :  {'date': '2020-09-18', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-19
# available_for_checkin :  True
# price :  {'date': '2020-09-19', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-20
# available_for_checkin :  True
# price :  {'date': '2020-09-20', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-21
# available_for_checkin :  True
# price :  {'date': '2020-09-21', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-22
# available_for_checkin :  True
# price :  {'date': '2020-09-22', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-23
# available_for_checkin :  True
# price :  {'date': '2020-09-23', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-24
# available_for_checkin :  True
# price :  {'date': '2020-09-24', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-25
# available_for_checkin :  True
# price :  {'date': '2020-09-25', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-26
# available_for_checkin :  True
# price :  {'date': '2020-09-26', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-27
# available_for_checkin :  True
# price :  {'date': '2020-09-27', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-28
# available_for_checkin :  True
# price :  {'date': '2020-09-28', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-29
# available_for_checkin :  True
# price :  {'date': '2020-09-29', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-09-30
# available_for_checkin :  True
# price :  {'date': '2020-09-30', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-10-01
# available_for_checkin :  True
# price :  {'date': '2020-10-01', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-10-02
# available_for_checkin :  True
# price :  {'date': '2020-10-02', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125
#
# Data type of day:  <class 'dict'>
# available :  True
# date :  2020-10-03
# available_for_checkin :  True
# price :  {'date': '2020-10-03', 'is_price_upon_request': None, 'local_adjusted_price': 120, 'local_currency': 'USD', 'local_price': 120, 'native_adjusted_price': 120, 'native_currency': 'USD', 'native_price': 120.0, 'type': 'demand_based_pricing', 'local_price_formatted': '$120'}
# min_nights :  8
# max_nights :  1125

# %%
import requests

search_url = 'https://buckets.peterbeshai.com/api/?player=201939&season=2015'
header = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36"}
response = requests.get(search_url, headers=header)

root=response.json()
#print(type(root))
#print(root)


jumpShots = 0
madeShots = 0
madeShots = 0
for i in range(0,len(root)):
    if root[i]['ACTION_TYPE'] == 'Jump Shot':
        jumpShots = jumpShots + 1
        if root[i]['EVENT_TYPE'] == 'Made Shot':
            madeShots = madeShots + 1

percentage = madeShots / jumpShots
print('WSSTENCEL')
print(jumpShots)
print(madeShots)
print("{:.2%}".format(percentage))
print('\nroot type', type(root))
print("\nSample of JSON structure 'root[0]['ACTION_TYPE']'")
print(root[0]['ACTION_TYPE'])
print("\nSample of JSON structure 'root[0]'")
print(root[0])
# Out:
# WSSTENCEL
# 743
# 244
# 32.84%
#
# root type <class 'list'>
#
# Sample of JSON structure 'root[0]['ACTION_TYPE']'
# Jump Shot
#
# Sample of JSON structure 'root[0]'
# {'ID': 127029798, 'GAME_ID': '0021500622', 'PLAYER_ID': 201939, 'TEAM_ID': 1610612744, 'SEASON': '2015', 'GAME_EVENT_ID': 344, 'PERIOD': 3, 'MINUTES_REMAINING': 5, 'SECONDS_REMAINING': 4, 'EVENT_TYPE': 'Made Shot', 'ACTION_TYPE': 'Jump Shot', 'SHOT_TYPE': '3PT Field Goal', 'SHOT_ZONE_BASIC': 'Left Corner 3', 'SHOT_ZONE_AREA': 'Left Side(L)', 'SHOT_ZONE_RANGE': '24+ ft.', 'SHOT_DISTANCE': 24, 'LOC_X': -245, 'LOC_Y': 13, 'SHOT_ATTEMPTED_FLAG': 1, 'SHOT_MADE_FLAG': 1}
